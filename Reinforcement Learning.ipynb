# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading https://files.pythonhosted.org/packages/8f/1f/edf9611bc202069790e4d43a3bb70550fc1a9b22649b8666efe41b3601ec/gym-0.12.4.tar.gz (1.5MB)
# Requirement already satisfied: scipy in c:\users\deepika\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.2.1)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\deepika\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.16.1)
# Requirement already satisfied: six in c:\users\deepika\appdata\local\programs\python\python35\lib\site-packages (from gym) (1.12.0)
# Collecting pyglet>=1.2.0 (from gym)
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
# Collecting future (from pyglet>=1.2.0->gym)
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
# Building wheels for collected packages: gym, future
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Deepika\AppData\Local\pip\Cache\wheels\bb\53\4d\2b8728cbdd500a073178cd90e0221b2ccd7caee595ed612285
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Deepika\AppData\Local\pip\Cache\wheels\0c\61\d2\d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
# Successfully built gym future
# Installing collected packages: future, pyglet, gym
# Successfully installed future-0.17.1 gym-0.12.4 pyglet-1.3.2
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # Reinforcement learning

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Random Action Selection On a Game

# %%
## creating a cartpole event
env = gym.make('CartPole-v0')

## e is the iterator over all the episodes
for e in range(20):
    observation = env.reset()
  
    for t in range(50):
        env.render()
        ## selecting the address from the address space
        action = env.action_space.sample()
    
        ## env.step function returns the observation, reward, done or not, other_info
    
        observation, reward, done, other_info = env.step(action)
    
        if done:
            print("Your highscore = {} and Game episode is {}".format(t, e))
            break
env.close()
# Out:
# Your highscore = 26 and Game episode is 0
# Your highscore = 20 and Game episode is 1
# Your highscore = 49 and Game episode is 2
# Your highscore = 9 and Game episode is 3
# Your highscore = 15 and Game episode is 4
# Your highscore = 21 and Game episode is 5
# Your highscore = 10 and Game episode is 6
# Your highscore = 11 and Game episode is 7
# Your highscore = 30 and Game episode is 8
# Your highscore = 15 and Game episode is 9
# Your highscore = 22 and Game episode is 10
# Your highscore = 14 and Game episode is 11
# Your highscore = 27 and Game episode is 12
# Your highscore = 22 and Game episode is 13
# Your highscore = 26 and Game episode is 14
# Your highscore = 42 and Game episode is 15
# Your highscore = 11 and Game episode is 16
# Your highscore = 20 and Game episode is 17
# Your highscore = 8 and Game episode is 18
# Your highscore = 24 and Game episode is 19

# %% [markdown]
# # Creating an AI Agent based on Neural Network

# %%
from collections import deque

# %%
class Agent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen = 2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        
        self.model = self._create_model()
        
    def _create_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim = self.state_size, activation = 'relu'))
        model.add(Dense(24, activation = 'relu'))
        model.add(Dense(self.action_size, activation = 'linear'))
        model.compile(loss = 'mse', optimizer = Adam(lr = self.learning_rate))
        return model
    
    def remember(self, state, action, reward, next_state, done):
        
        self.memory.append((state, action, reward, next_state, done))
        
    def act(self, state):
        
        if np.random.rand() <= self.epsilon:
            
            return random.randrange(self.action_size)
        
        return np.argmax(self.model.predict(state)[0])
    
    def train(self, batch_size = 32):
        ## replay buffer training
        
        minibatch = random.sample(self.memory, batch_size)
        
        for experience in minibatch:
            state, action, reward, next_state, done = experience
            
            if not done:
                
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
                
            else:
                target = reward
                
            target_f = self.model.predict(state)
            
            target_f[0][action] = target
            
            self.model.fit(state, target_f, epochs = 1, verbose = 0)
        
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
            
    def load(self, name):
        self.model.load_weights(name)
        
    def save(self, name):
        self.model.save_weights(name)

# %%
n_episodes = 1000
state_size = 4
action_size = 2
done = False

# %%
agent = Agent(state_size = 4, action_size = 2)

# %%
for e in range(n_episodes):
    
    state = env.reset()
    state = np.reshape(state, [1, state_size])
    for t in range(500):
        env.render()
        action = agent.act(state)
        
        next_state, reward, done, other_info = env.step(action)
        
        reward = reward if not done else -10
        
        next_state = np.reshape(next_state, [1, state_size])
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state
        
        if done :
            print("Your highscore = {} and Game episode is {}, exploration_rate is {}".format(t, e, agent.epsilon))
            break
            
    if len(agent.memory) > 32:
        agent.train(32)
env.close()
# Out:
# Your highscore = 56 and Game episode is 0, exploration_rate is 1.0
# Your highscore = 12 and Game episode is 1, exploration_rate is 0.995
# Your highscore = 23 and Game episode is 2, exploration_rate is 0.990025
# Your highscore = 40 and Game episode is 3, exploration_rate is 0.985074875
# Your highscore = 14 and Game episode is 4, exploration_rate is 0.9801495006250001
# Your highscore = 13 and Game episode is 5, exploration_rate is 0.9752487531218751
# Your highscore = 35 and Game episode is 6, exploration_rate is 0.9703725093562657
# Your highscore = 22 and Game episode is 7, exploration_rate is 0.9655206468094844
# Your highscore = 12 and Game episode is 8, exploration_rate is 0.960693043575437
# Your highscore = 10 and Game episode is 9, exploration_rate is 0.9558895783575597
# Your highscore = 46 and Game episode is 10, exploration_rate is 0.9511101304657719
# Your highscore = 23 and Game episode is 11, exploration_rate is 0.946354579813443
# Your highscore = 50 and Game episode is 12, exploration_rate is 0.9416228069143757
# Your highscore = 16 and Game episode is 13, exploration_rate is 0.9369146928798039
# Your highscore = 38 and Game episode is 14, exploration_rate is 0.9322301194154049
# Your highscore = 15 and Game episode is 15, exploration_rate is 0.9275689688183278
# Your highscore = 13 and Game episode is 16, exploration_rate is 0.9229311239742362
# Your highscore = 17 and Game episode is 17, exploration_rate is 0.918316468354365
# Your highscore = 23 and Game episode is 18, exploration_rate is 0.9137248860125932
# Your highscore = 21 and Game episode is 19, exploration_rate is 0.9091562615825302
# Your highscore = 34 and Game episode is 20, exploration_rate is 0.9046104802746175
# Your highscore = 18 and Game episode is 21, exploration_rate is 0.9000874278732445
# Your highscore = 10 and Game episode is 22, exploration_rate is 0.8955869907338783
# Your highscore = 10 and Game episode is 23, exploration_rate is 0.8911090557802088
# Your highscore = 9 and Game episode is 24, exploration_rate is 0.8866535105013078
# Your highscore = 19 and Game episode is 25, exploration_rate is 0.8822202429488013
# Your highscore = 27 and Game episode is 26, exploration_rate is 0.8778091417340573
# Your highscore = 32 and Game episode is 27, exploration_rate is 0.8734200960253871
# Your highscore = 24 and Game episode is 28, exploration_rate is 0.8690529955452602
# Your highscore = 18 and Game episode is 29, exploration_rate is 0.8647077305675338
# Your highscore = 18 and Game episode is 30, exploration_rate is 0.8603841919146962
# Your highscore = 33 and Game episode is 31, exploration_rate is 0.8560822709551227
# Your highscore = 16 and Game episode is 32, exploration_rate is 0.851801859600347
# Your highscore = 11 and Game episode is 33, exploration_rate is 0.8475428503023453
# Your highscore = 13 and Game episode is 34, exploration_rate is 0.8433051360508336
# Your highscore = 44 and Game episode is 35, exploration_rate is 0.8390886103705794
# Your highscore = 15 and Game episode is 36, exploration_rate is 0.8348931673187264
# Your highscore = 9 and Game episode is 37, exploration_rate is 0.8307187014821328
# Your highscore = 19 and Game episode is 38, exploration_rate is 0.8265651079747222
# Your highscore = 11 and Game episode is 39, exploration_rate is 0.8224322824348486
# Your highscore = 19 and Game episode is 40, exploration_rate is 0.8183201210226743
# Your highscore = 13 and Game episode is 41, exploration_rate is 0.8142285204175609
# Your highscore = 12 and Game episode is 42, exploration_rate is 0.810157377815473
# Your highscore = 11 and Game episode is 43, exploration_rate is 0.8061065909263957
# Your highscore = 12 and Game episode is 44, exploration_rate is 0.8020760579717637
# Your highscore = 21 and Game episode is 45, exploration_rate is 0.798065677681905
# Your highscore = 15 and Game episode is 46, exploration_rate is 0.7940753492934954
# Your highscore = 14 and Game episode is 47, exploration_rate is 0.7901049725470279
# Your highscore = 9 and Game episode is 48, exploration_rate is 0.7861544476842928
# Your highscore = 9 and Game episode is 49, exploration_rate is 0.7822236754458713
# Your highscore = 30 and Game episode is 50, exploration_rate is 0.778312557068642
# Your highscore = 12 and Game episode is 51, exploration_rate is 0.7744209942832988
# Your highscore = 11 and Game episode is 52, exploration_rate is 0.7705488893118823
# Your highscore = 10 and Game episode is 53, exploration_rate is 0.7666961448653229
# Your highscore = 33 and Game episode is 54, exploration_rate is 0.7628626641409962
# Your highscore = 15 and Game episode is 55, exploration_rate is 0.7590483508202912
# Your highscore = 9 and Game episode is 56, exploration_rate is 0.7552531090661897
# Your highscore = 17 and Game episode is 57, exploration_rate is 0.7514768435208588
# Your highscore = 13 and Game episode is 58, exploration_rate is 0.7477194593032545
# Your highscore = 13 and Game episode is 59, exploration_rate is 0.7439808620067382
# Your highscore = 39 and Game episode is 60, exploration_rate is 0.7402609576967045
# Your highscore = 9 and Game episode is 61, exploration_rate is 0.736559652908221
# Your highscore = 17 and Game episode is 62, exploration_rate is 0.7328768546436799
# Your highscore = 26 and Game episode is 63, exploration_rate is 0.7292124703704616
# Your highscore = 14 and Game episode is 64, exploration_rate is 0.7255664080186093
# Your highscore = 9 and Game episode is 65, exploration_rate is 0.7219385759785162
# Your highscore = 18 and Game episode is 66, exploration_rate is 0.7183288830986236
# Your highscore = 35 and Game episode is 67, exploration_rate is 0.7147372386831305
# Your highscore = 12 and Game episode is 68, exploration_rate is 0.7111635524897149
# Your highscore = 16 and Game episode is 69, exploration_rate is 0.7076077347272662
# Your highscore = 11 and Game episode is 70, exploration_rate is 0.7040696960536299
# Your highscore = 24 and Game episode is 71, exploration_rate is 0.7005493475733617
# Your highscore = 12 and Game episode is 72, exploration_rate is 0.697046600835495
# Your highscore = 12 and Game episode is 73, exploration_rate is 0.6935613678313175
# Your highscore = 15 and Game episode is 74, exploration_rate is 0.6900935609921609
# Your highscore = 23 and Game episode is 75, exploration_rate is 0.6866430931872001
# Your highscore = 11 and Game episode is 76, exploration_rate is 0.6832098777212641
# Your highscore = 13 and Game episode is 77, exploration_rate is 0.6797938283326578
# Your highscore = 24 and Game episode is 78, exploration_rate is 0.6763948591909945
# Your highscore = 31 and Game episode is 79, exploration_rate is 0.6730128848950395
# Your highscore = 23 and Game episode is 80, exploration_rate is 0.6696478204705644
# Your highscore = 42 and Game episode is 81, exploration_rate is 0.6662995813682115
# Your highscore = 21 and Game episode is 82, exploration_rate is 0.6629680834613705
# Your highscore = 16 and Game episode is 83, exploration_rate is 0.6596532430440636
# Your highscore = 10 and Game episode is 84, exploration_rate is 0.6563549768288433
# Your highscore = 33 and Game episode is 85, exploration_rate is 0.653073201944699
# Your highscore = 63 and Game episode is 86, exploration_rate is 0.6498078359349755
# Your highscore = 43 and Game episode is 87, exploration_rate is 0.6465587967553006
# Your highscore = 27 and Game episode is 88, exploration_rate is 0.6433260027715241
# Your highscore = 37 and Game episode is 89, exploration_rate is 0.6401093727576664
# Your highscore = 95 and Game episode is 90, exploration_rate is 0.6369088258938781
# Your highscore = 30 and Game episode is 91, exploration_rate is 0.6337242817644086
# Your highscore = 31 and Game episode is 92, exploration_rate is 0.6305556603555866
# Your highscore = 18 and Game episode is 93, exploration_rate is 0.6274028820538087
# Your highscore = 11 and Game episode is 94, exploration_rate is 0.6242658676435396
# Your highscore = 51 and Game episode is 95, exploration_rate is 0.6211445383053219
# Your highscore = 36 and Game episode is 96, exploration_rate is 0.6180388156137953
# Your highscore = 18 and Game episode is 97, exploration_rate is 0.6149486215357263
# Your highscore = 13 and Game episode is 98, exploration_rate is 0.6118738784280476
# Your highscore = 38 and Game episode is 99, exploration_rate is 0.6088145090359074
# Your highscore = 59 and Game episode is 100, exploration_rate is 0.6057704364907278
# Your highscore = 37 and Game episode is 101, exploration_rate is 0.6027415843082742
# Your highscore = 82 and Game episode is 102, exploration_rate is 0.5997278763867329
# Your highscore = 154 and Game episode is 103, exploration_rate is 0.5967292370047992
# Your highscore = 33 and Game episode is 104, exploration_rate is 0.5937455908197752
# Your highscore = 19 and Game episode is 105, exploration_rate is 0.5907768628656763
# Your highscore = 41 and Game episode is 106, exploration_rate is 0.5878229785513479
# Your highscore = 54 and Game episode is 107, exploration_rate is 0.5848838636585911
# Your highscore = 37 and Game episode is 108, exploration_rate is 0.5819594443402982
# Your highscore = 57 and Game episode is 109, exploration_rate is 0.5790496471185967
# Your highscore = 30 and Game episode is 110, exploration_rate is 0.5761543988830038
# Your highscore = 47 and Game episode is 111, exploration_rate is 0.5732736268885887
# Your highscore = 26 and Game episode is 112, exploration_rate is 0.5704072587541458
# Your highscore = 52 and Game episode is 113, exploration_rate is 0.567555222460375
# Your highscore = 127 and Game episode is 114, exploration_rate is 0.5647174463480732
# Your highscore = 84 and Game episode is 115, exploration_rate is 0.5618938591163328
# Your highscore = 31 and Game episode is 116, exploration_rate is 0.5590843898207511
# Your highscore = 25 and Game episode is 117, exploration_rate is 0.5562889678716474
# Your highscore = 32 and Game episode is 118, exploration_rate is 0.5535075230322891
# Your highscore = 27 and Game episode is 119, exploration_rate is 0.5507399854171277
# Your highscore = 68 and Game episode is 120, exploration_rate is 0.547986285490042
# Your highscore = 34 and Game episode is 121, exploration_rate is 0.5452463540625918
# Your highscore = 20 and Game episode is 122, exploration_rate is 0.5425201222922789
# Your highscore = 71 and Game episode is 123, exploration_rate is 0.5398075216808175
# Your highscore = 19 and Game episode is 124, exploration_rate is 0.5371084840724134
# Your highscore = 30 and Game episode is 125, exploration_rate is 0.5344229416520513
# Your highscore = 18 and Game episode is 126, exploration_rate is 0.531750826943791
# Your highscore = 22 and Game episode is 127, exploration_rate is 0.5290920728090721
# Your highscore = 82 and Game episode is 128, exploration_rate is 0.5264466124450268
# Your highscore = 60 and Game episode is 129, exploration_rate is 0.5238143793828016
# Your highscore = 109 and Game episode is 130, exploration_rate is 0.5211953074858876
# Your highscore = 88 and Game episode is 131, exploration_rate is 0.5185893309484582
# Your highscore = 60 and Game episode is 132, exploration_rate is 0.5159963842937159
# Your highscore = 69 and Game episode is 133, exploration_rate is 0.5134164023722473
# Your highscore = 76 and Game episode is 134, exploration_rate is 0.510849320360386
# Your highscore = 106 and Game episode is 135, exploration_rate is 0.5082950737585841
# Your highscore = 44 and Game episode is 136, exploration_rate is 0.5057535983897912
# Your highscore = 93 and Game episode is 137, exploration_rate is 0.5032248303978422
# Your highscore = 32 and Game episode is 138, exploration_rate is 0.500708706245853
# Your highscore = 47 and Game episode is 139, exploration_rate is 0.4982051627146237
# Your highscore = 32 and Game episode is 140, exploration_rate is 0.49571413690105054
# Your highscore = 109 and Game episode is 141, exploration_rate is 0.4932355662165453
# Your highscore = 10 and Game episode is 142, exploration_rate is 0.4907693883854626
# Your highscore = 14 and Game episode is 143, exploration_rate is 0.4883155414435353
# Your highscore = 17 and Game episode is 144, exploration_rate is 0.4858739637363176
# Your highscore = 22 and Game episode is 145, exploration_rate is 0.483444593917636
# Your highscore = 39 and Game episode is 146, exploration_rate is 0.4810273709480478
# Your highscore = 22 and Game episode is 147, exploration_rate is 0.47862223409330756
# Your highscore = 38 and Game episode is 148, exploration_rate is 0.47622912292284103
# Your highscore = 12 and Game episode is 149, exploration_rate is 0.4738479773082268
# Your highscore = 83 and Game episode is 150, exploration_rate is 0.47147873742168567
# Your highscore = 15 and Game episode is 151, exploration_rate is 0.46912134373457726
# Your highscore = 23 and Game episode is 152, exploration_rate is 0.46677573701590436
# Your highscore = 29 and Game episode is 153, exploration_rate is 0.46444185833082485
# Your highscore = 60 and Game episode is 154, exploration_rate is 0.46211964903917074
# Your highscore = 16 and Game episode is 155, exploration_rate is 0.4598090507939749
# Your highscore = 50 and Game episode is 156, exploration_rate is 0.457510005540005
# Your highscore = 42 and Game episode is 157, exploration_rate is 0.45522245551230495
# Your highscore = 92 and Game episode is 158, exploration_rate is 0.4529463432347434
# Your highscore = 50 and Game episode is 159, exploration_rate is 0.4506816115185697
# Your highscore = 38 and Game episode is 160, exploration_rate is 0.4484282034609769
# Your highscore = 45 and Game episode is 161, exploration_rate is 0.446186062443672
# Your highscore = 29 and Game episode is 162, exploration_rate is 0.4439551321314536
# Your highscore = 24 and Game episode is 163, exploration_rate is 0.4417353564707963
# Your highscore = 65 and Game episode is 164, exploration_rate is 0.43952667968844233
# Your highscore = 47 and Game episode is 165, exploration_rate is 0.43732904629000013
# Your highscore = 58 and Game episode is 166, exploration_rate is 0.4351424010585501
# Your highscore = 18 and Game episode is 167, exploration_rate is 0.43296668905325736
# Your highscore = 32 and Game episode is 168, exploration_rate is 0.43080185560799106
# Your highscore = 44 and Game episode is 169, exploration_rate is 0.4286478463299511
# Your highscore = 31 and Game episode is 170, exploration_rate is 0.42650460709830135
# Your highscore = 63 and Game episode is 171, exploration_rate is 0.42437208406280985
# Your highscore = 52 and Game episode is 172, exploration_rate is 0.4222502236424958
# Your highscore = 35 and Game episode is 173, exploration_rate is 0.42013897252428334
# Your highscore = 28 and Game episode is 174, exploration_rate is 0.4180382776616619
# Your highscore = 18 and Game episode is 175, exploration_rate is 0.4159480862733536
# Your highscore = 16 and Game episode is 176, exploration_rate is 0.41386834584198684
# Your highscore = 84 and Game episode is 177, exploration_rate is 0.4117990041127769
# Your highscore = 45 and Game episode is 178, exploration_rate is 0.40974000909221303
# Your highscore = 119 and Game episode is 179, exploration_rate is 0.40769130904675194
# Your highscore = 37 and Game episode is 180, exploration_rate is 0.40565285250151817
# Your highscore = 42 and Game episode is 181, exploration_rate is 0.4036245882390106
# Your highscore = 47 and Game episode is 182, exploration_rate is 0.4016064652978155
# Your highscore = 31 and Game episode is 183, exploration_rate is 0.3995984329713264
# Your highscore = 47 and Game episode is 184, exploration_rate is 0.3976004408064698
# Your highscore = 17 and Game episode is 185, exploration_rate is 0.39561243860243744
# Your highscore = 30 and Game episode is 186, exploration_rate is 0.3936343764094253
# Your highscore = 30 and Game episode is 187, exploration_rate is 0.39166620452737816
# Your highscore = 22 and Game episode is 188, exploration_rate is 0.3897078735047413
# Your highscore = 21 and Game episode is 189, exploration_rate is 0.3877593341372176
# Your highscore = 24 and Game episode is 190, exploration_rate is 0.3858205374665315
# Your highscore = 32 and Game episode is 191, exploration_rate is 0.38389143477919885
# Your highscore = 75 and Game episode is 192, exploration_rate is 0.3819719776053028
# Your highscore = 15 and Game episode is 193, exploration_rate is 0.3800621177172763
# Your highscore = 54 and Game episode is 194, exploration_rate is 0.37816180712868996
# Your highscore = 85 and Game episode is 195, exploration_rate is 0.37627099809304654
# Your highscore = 66 and Game episode is 196, exploration_rate is 0.3743896431025813
# Your highscore = 25 and Game episode is 197, exploration_rate is 0.37251769488706843
# Your highscore = 57 and Game episode is 198, exploration_rate is 0.3706551064126331
# Your highscore = 82 and Game episode is 199, exploration_rate is 0.36880183088056995
# Your highscore = 106 and Game episode is 200, exploration_rate is 0.3669578217261671
# Your highscore = 40 and Game episode is 201, exploration_rate is 0.36512303261753626
# Your highscore = 37 and Game episode is 202, exploration_rate is 0.3632974174544486
# Your highscore = 50 and Game episode is 203, exploration_rate is 0.3614809303671764
# Your highscore = 21 and Game episode is 204, exploration_rate is 0.3596735257153405
# Your highscore = 19 and Game episode is 205, exploration_rate is 0.3578751580867638
# Your highscore = 28 and Game episode is 206, exploration_rate is 0.35608578229633
# Your highscore = 23 and Game episode is 207, exploration_rate is 0.3543053533848483
# Your highscore = 23 and Game episode is 208, exploration_rate is 0.35253382661792404
# Your highscore = 53 and Game episode is 209, exploration_rate is 0.3507711574848344
# Your highscore = 41 and Game episode is 210, exploration_rate is 0.34901730169741024
# Your highscore = 35 and Game episode is 211, exploration_rate is 0.3472722151889232
# Your highscore = 23 and Game episode is 212, exploration_rate is 0.3455358541129786
# Your highscore = 14 and Game episode is 213, exploration_rate is 0.3438081748424137
# Your highscore = 50 and Game episode is 214, exploration_rate is 0.3420891339682016
# Your highscore = 14 and Game episode is 215, exploration_rate is 0.3403786882983606
# Your highscore = 38 and Game episode is 216, exploration_rate is 0.3386767948568688
# Your highscore = 32 and Game episode is 217, exploration_rate is 0.33698341088258443
# Your highscore = 43 and Game episode is 218, exploration_rate is 0.3352984938281715
# Your highscore = 78 and Game episode is 219, exploration_rate is 0.33362200135903064
# Your highscore = 63 and Game episode is 220, exploration_rate is 0.33195389135223546
# Your highscore = 30 and Game episode is 221, exploration_rate is 0.3302941218954743
# Your highscore = 28 and Game episode is 222, exploration_rate is 0.32864265128599696
# Your highscore = 22 and Game episode is 223, exploration_rate is 0.326999438029567
# Your highscore = 49 and Game episode is 224, exploration_rate is 0.3253644408394192
# Your highscore = 61 and Game episode is 225, exploration_rate is 0.3237376186352221
# Your highscore = 134 and Game episode is 226, exploration_rate is 0.322118930542046
# Your highscore = 42 and Game episode is 227, exploration_rate is 0.32050833588933575
# Your highscore = 88 and Game episode is 228, exploration_rate is 0.31890579420988907
# Your highscore = 71 and Game episode is 229, exploration_rate is 0.3173112652388396
# Your highscore = 51 and Game episode is 230, exploration_rate is 0.3157247089126454
# Your highscore = 178 and Game episode is 231, exploration_rate is 0.3141460853680822
# Your highscore = 138 and Game episode is 232, exploration_rate is 0.3125753549412418
# Your highscore = 69 and Game episode is 233, exploration_rate is 0.31101247816653554
# Your highscore = 199 and Game episode is 234, exploration_rate is 0.30945741577570285
# Your highscore = 125 and Game episode is 235, exploration_rate is 0.3079101286968243
# Your highscore = 103 and Game episode is 236, exploration_rate is 0.3063705780533402
# Your highscore = 145 and Game episode is 237, exploration_rate is 0.30483872516307353
# Your highscore = 199 and Game episode is 238, exploration_rate is 0.3033145315372582
# Your highscore = 91 and Game episode is 239, exploration_rate is 0.3017979588795719
# Your highscore = 175 and Game episode is 240, exploration_rate is 0.30028896908517405
# Your highscore = 139 and Game episode is 241, exploration_rate is 0.2987875242397482
# Your highscore = 163 and Game episode is 242, exploration_rate is 0.29729358661854943
# Your highscore = 199 and Game episode is 243, exploration_rate is 0.29580711868545667
# Your highscore = 199 and Game episode is 244, exploration_rate is 0.2943280830920294
# Your highscore = 134 and Game episode is 245, exploration_rate is 0.29285644267656924
# Your highscore = 199 and Game episode is 246, exploration_rate is 0.2913921604631864
# Your highscore = 199 and Game episode is 247, exploration_rate is 0.28993519966087045
# Your highscore = 111 and Game episode is 248, exploration_rate is 0.2884855236625661
# Your highscore = 158 and Game episode is 249, exploration_rate is 0.28704309604425327
# Your highscore = 66 and Game episode is 250, exploration_rate is 0.285607880564032
# Your highscore = 199 and Game episode is 251, exploration_rate is 0.28417984116121187
# Your highscore = 122 and Game episode is 252, exploration_rate is 0.2827589419554058
# Your highscore = 84 and Game episode is 253, exploration_rate is 0.28134514724562876
# Your highscore = 168 and Game episode is 254, exploration_rate is 0.2799384215094006
# Your highscore = 135 and Game episode is 255, exploration_rate is 0.27853872940185365
# Your highscore = 199 and Game episode is 256, exploration_rate is 0.27714603575484437
# Your highscore = 88 and Game episode is 257, exploration_rate is 0.2757603055760701
# Your highscore = 199 and Game episode is 258, exploration_rate is 0.2743815040481898
# Your highscore = 67 and Game episode is 259, exploration_rate is 0.2730095965279488
# Your highscore = 76 and Game episode is 260, exploration_rate is 0.27164454854530906
# Your highscore = 165 and Game episode is 261, exploration_rate is 0.2702863258025825
# Your highscore = 39 and Game episode is 262, exploration_rate is 0.2689348941735696
# Your highscore = 34 and Game episode is 263, exploration_rate is 0.26759021970270175
# Your highscore = 44 and Game episode is 264, exploration_rate is 0.2662522686041882
# Your highscore = 49 and Game episode is 265, exploration_rate is 0.2649210072611673
# Your highscore = 57 and Game episode is 266, exploration_rate is 0.26359640222486147
# Your highscore = 119 and Game episode is 267, exploration_rate is 0.26227842021373715
# Your highscore = 102 and Game episode is 268, exploration_rate is 0.2609670281126685
# Your highscore = 23 and Game episode is 269, exploration_rate is 0.25966219297210513
# Your highscore = 104 and Game episode is 270, exploration_rate is 0.2583638820072446
# Your highscore = 50 and Game episode is 271, exploration_rate is 0.2570720625972084
# Your highscore = 133 and Game episode is 272, exploration_rate is 0.25578670228422234
# Your highscore = 180 and Game episode is 273, exploration_rate is 0.25450776877280124
# Your highscore = 146 and Game episode is 274, exploration_rate is 0.2532352299289372
# Your highscore = 180 and Game episode is 275, exploration_rate is 0.2519690537792925
# Your highscore = 130 and Game episode is 276, exploration_rate is 0.2507092085103961
# Your highscore = 97 and Game episode is 277, exploration_rate is 0.2494556624678441
# Your highscore = 123 and Game episode is 278, exploration_rate is 0.24820838415550486
# Your highscore = 92 and Game episode is 279, exploration_rate is 0.24696734223472733
# Your highscore = 199 and Game episode is 280, exploration_rate is 0.2457325055235537
# Your highscore = 171 and Game episode is 281, exploration_rate is 0.24450384299593592
# Your highscore = 165 and Game episode is 282, exploration_rate is 0.24328132378095624
# Your highscore = 199 and Game episode is 283, exploration_rate is 0.24206491716205145
# Your highscore = 66 and Game episode is 284, exploration_rate is 0.2408545925762412
# Your highscore = 80 and Game episode is 285, exploration_rate is 0.23965031961336
# Your highscore = 143 and Game episode is 286, exploration_rate is 0.2384520680152932
# Your highscore = 105 and Game episode is 287, exploration_rate is 0.23725980767521673
# Your highscore = 68 and Game episode is 288, exploration_rate is 0.23607350863684065
# Your highscore = 61 and Game episode is 289, exploration_rate is 0.23489314109365644
# Your highscore = 62 and Game episode is 290, exploration_rate is 0.23371867538818816
# Your highscore = 110 and Game episode is 291, exploration_rate is 0.23255008201124722
# Your highscore = 199 and Game episode is 292, exploration_rate is 0.231387331601191
# Your highscore = 156 and Game episode is 293, exploration_rate is 0.23023039494318503
# Your highscore = 64 and Game episode is 294, exploration_rate is 0.2290792429684691
# Your highscore = 53 and Game episode is 295, exploration_rate is 0.22793384675362674
# Your highscore = 67 and Game episode is 296, exploration_rate is 0.22679417751985861
# Your highscore = 100 and Game episode is 297, exploration_rate is 0.22566020663225933
# Your highscore = 180 and Game episode is 298, exploration_rate is 0.22453190559909803
# Your highscore = 114 and Game episode is 299, exploration_rate is 0.22340924607110255
# Your highscore = 120 and Game episode is 300, exploration_rate is 0.22229219984074702
# Your highscore = 84 and Game episode is 301, exploration_rate is 0.2211807388415433
# Your highscore = 78 and Game episode is 302, exploration_rate is 0.22007483514733558
# Your highscore = 147 and Game episode is 303, exploration_rate is 0.2189744609715989
# Your highscore = 140 and Game episode is 304, exploration_rate is 0.2178795886667409
# Your highscore = 194 and Game episode is 305, exploration_rate is 0.2167901907234072
# Your highscore = 113 and Game episode is 306, exploration_rate is 0.21570623976979014
# Your highscore = 199 and Game episode is 307, exploration_rate is 0.21462770857094118
# Your highscore = 19 and Game episode is 308, exploration_rate is 0.21355457002808648
# Your highscore = 15 and Game episode is 309, exploration_rate is 0.21248679717794605
# Your highscore = 199 and Game episode is 310, exploration_rate is 0.21142436319205632
# Your highscore = 186 and Game episode is 311, exploration_rate is 0.21036724137609603
# Your highscore = 162 and Game episode is 312, exploration_rate is 0.20931540516921554
# Your highscore = 190 and Game episode is 313, exploration_rate is 0.20826882814336947
# Your highscore = 199 and Game episode is 314, exploration_rate is 0.20722748400265262
# Your highscore = 199 and Game episode is 315, exploration_rate is 0.20619134658263935
# Your highscore = 123 and Game episode is 316, exploration_rate is 0.20516038984972615
# Your highscore = 117 and Game episode is 317, exploration_rate is 0.2041345879004775
# Your highscore = 98 and Game episode is 318, exploration_rate is 0.2031139149609751
# Your highscore = 178 and Game episode is 319, exploration_rate is 0.20209834538617025
# Your highscore = 132 and Game episode is 320, exploration_rate is 0.2010878536592394
# Your highscore = 156 and Game episode is 321, exploration_rate is 0.2000824143909432
# Your highscore = 196 and Game episode is 322, exploration_rate is 0.19908200231898848
# Your highscore = 68 and Game episode is 323, exploration_rate is 0.19808659230739353
# Your highscore = 184 and Game episode is 324, exploration_rate is 0.19709615934585656
# Your highscore = 199 and Game episode is 325, exploration_rate is 0.19611067854912728
# Your highscore = 126 and Game episode is 326, exploration_rate is 0.19513012515638165
# Your highscore = 179 and Game episode is 327, exploration_rate is 0.19415447453059972
# Your highscore = 160 and Game episode is 328, exploration_rate is 0.19318370215794672
# Your highscore = 107 and Game episode is 329, exploration_rate is 0.192217783647157
# Your highscore = 199 and Game episode is 330, exploration_rate is 0.1912566947289212
# Your highscore = 188 and Game episode is 331, exploration_rate is 0.1903004112552766
# Your highscore = 146 and Game episode is 332, exploration_rate is 0.18934890919900021
# Your highscore = 127 and Game episode is 333, exploration_rate is 0.18840216465300522
# Your highscore = 168 and Game episode is 334, exploration_rate is 0.18746015382974018
# Your highscore = 124 and Game episode is 335, exploration_rate is 0.1865228530605915
# Your highscore = 40 and Game episode is 336, exploration_rate is 0.18559023879528855
# Your highscore = 159 and Game episode is 337, exploration_rate is 0.1846622876013121
# Your highscore = 127 and Game episode is 338, exploration_rate is 0.18373897616330553
# Your highscore = 199 and Game episode is 339, exploration_rate is 0.182820281282489
# Your highscore = 126 and Game episode is 340, exploration_rate is 0.18190617987607657
# Your highscore = 195 and Game episode is 341, exploration_rate is 0.18099664897669618
# Your highscore = 73 and Game episode is 342, exploration_rate is 0.1800916657318127
# Your highscore = 50 and Game episode is 343, exploration_rate is 0.17919120740315364
# Your highscore = 70 and Game episode is 344, exploration_rate is 0.17829525136613786
# Your highscore = 135 and Game episode is 345, exploration_rate is 0.17740377510930716
# Your highscore = 131 and Game episode is 346, exploration_rate is 0.17651675623376062
# Your highscore = 52 and Game episode is 347, exploration_rate is 0.1756341724525918
# Your highscore = 136 and Game episode is 348, exploration_rate is 0.17475600159032884
# Your highscore = 174 and Game episode is 349, exploration_rate is 0.17388222158237718
# Your highscore = 161 and Game episode is 350, exploration_rate is 0.1730128104744653
# Your highscore = 197 and Game episode is 351, exploration_rate is 0.17214774642209296
# Your highscore = 199 and Game episode is 352, exploration_rate is 0.1712870076899825
# Your highscore = 199 and Game episode is 353, exploration_rate is 0.17043057265153258
# Your highscore = 199 and Game episode is 354, exploration_rate is 0.16957841978827493
# Your highscore = 166 and Game episode is 355, exploration_rate is 0.16873052768933355
# Your highscore = 131 and Game episode is 356, exploration_rate is 0.1678868750508869
# Your highscore = 199 and Game episode is 357, exploration_rate is 0.16704744067563246
# Your highscore = 199 and Game episode is 358, exploration_rate is 0.1662122034722543
# Your highscore = 199 and Game episode is 359, exploration_rate is 0.16538114245489302
# Your highscore = 199 and Game episode is 360, exploration_rate is 0.16455423674261854
# Your highscore = 199 and Game episode is 361, exploration_rate is 0.16373146555890544
# Your highscore = 182 and Game episode is 362, exploration_rate is 0.16291280823111093
# Your highscore = 194 and Game episode is 363, exploration_rate is 0.16209824418995536
# Your highscore = 199 and Game episode is 364, exploration_rate is 0.16128775296900558
# Your highscore = 199 and Game episode is 365, exploration_rate is 0.16048131420416054
# Your highscore = 199 and Game episode is 366, exploration_rate is 0.15967890763313974
# Your highscore = 199 and Game episode is 367, exploration_rate is 0.15888051309497406
# Your highscore = 116 and Game episode is 368, exploration_rate is 0.1580861105294992
# Your highscore = 159 and Game episode is 369, exploration_rate is 0.1572956799768517
# Your highscore = 199 and Game episode is 370, exploration_rate is 0.15650920157696743
# Your highscore = 199 and Game episode is 371, exploration_rate is 0.1557266555690826
# Your highscore = 199 and Game episode is 372, exploration_rate is 0.1549480222912372
# Your highscore = 199 and Game episode is 373, exploration_rate is 0.15417328217978102
# Your highscore = 199 and Game episode is 374, exploration_rate is 0.1534024157688821
# Your highscore = 104 and Game episode is 375, exploration_rate is 0.1526354036900377
# Your highscore = 134 and Game episode is 376, exploration_rate is 0.1518722266715875
# Your highscore = 199 and Game episode is 377, exploration_rate is 0.15111286553822956
# Your highscore = 199 and Game episode is 378, exploration_rate is 0.15035730121053842
# Your highscore = 199 and Game episode is 379, exploration_rate is 0.14960551470448571
# Your highscore = 199 and Game episode is 380, exploration_rate is 0.14885748713096328
# Your highscore = 199 and Game episode is 381, exploration_rate is 0.14811319969530845
# Your highscore = 199 and Game episode is 382, exploration_rate is 0.1473726336968319
# Your highscore = 199 and Game episode is 383, exploration_rate is 0.14663577052834775
# Your highscore = 199 and Game episode is 384, exploration_rate is 0.14590259167570602
# Your highscore = 199 and Game episode is 385, exploration_rate is 0.1451730787173275
# Your highscore = 199 and Game episode is 386, exploration_rate is 0.14444721332374086
# Your highscore = 199 and Game episode is 387, exploration_rate is 0.14372497725712216
# Your highscore = 199 and Game episode is 388, exploration_rate is 0.14300635237083656
# Your highscore = 181 and Game episode is 389, exploration_rate is 0.14229132060898236
# Your highscore = 199 and Game episode is 390, exploration_rate is 0.14157986400593744
# Your highscore = 199 and Game episode is 391, exploration_rate is 0.14087196468590776
# Your highscore = 199 and Game episode is 392, exploration_rate is 0.14016760486247823
# Your highscore = 199 and Game episode is 393, exploration_rate is 0.13946676683816583
# Your highscore = 199 and Game episode is 394, exploration_rate is 0.138769433003975
# Your highscore = 119 and Game episode is 395, exploration_rate is 0.13807558583895513
# Your highscore = 199 and Game episode is 396, exploration_rate is 0.13738520790976036
# Your highscore = 199 and Game episode is 397, exploration_rate is 0.13669828187021155
# Your highscore = 199 and Game episode is 398, exploration_rate is 0.13601479046086049
# Your highscore = 199 and Game episode is 399, exploration_rate is 0.1353347165085562
# Your highscore = 199 and Game episode is 400, exploration_rate is 0.1346580429260134
# Your highscore = 199 and Game episode is 401, exploration_rate is 0.13398475271138335
# Your highscore = 199 and Game episode is 402, exploration_rate is 0.13331482894782642
# Your highscore = 199 and Game episode is 403, exploration_rate is 0.13264825480308728
# Your highscore = 199 and Game episode is 404, exploration_rate is 0.13198501352907185
# Your highscore = 199 and Game episode is 405, exploration_rate is 0.1313250884614265
# Your highscore = 199 and Game episode is 406, exploration_rate is 0.13066846301911936
# Your highscore = 199 and Game episode is 407, exploration_rate is 0.13001512070402377
# Your highscore = 199 and Game episode is 408, exploration_rate is 0.12936504510050365
# Your highscore = 199 and Game episode is 409, exploration_rate is 0.12871821987500112
# Your highscore = 199 and Game episode is 410, exploration_rate is 0.12807462877562611
# Your highscore = 127 and Game episode is 411, exploration_rate is 0.12743425563174798
# Your highscore = 199 and Game episode is 412, exploration_rate is 0.12679708435358925
# Your highscore = 199 and Game episode is 413, exploration_rate is 0.1261630989318213
# Your highscore = 199 and Game episode is 414, exploration_rate is 0.1255322834371622
# Your highscore = 199 and Game episode is 415, exploration_rate is 0.12490462201997637
# Your highscore = 199 and Game episode is 416, exploration_rate is 0.1242800989098765
# Your highscore = 199 and Game episode is 417, exploration_rate is 0.12365869841532712
# Your highscore = 199 and Game episode is 418, exploration_rate is 0.12304040492325048
# Your highscore = 199 and Game episode is 419, exploration_rate is 0.12242520289863423
# Your highscore = 199 and Game episode is 420, exploration_rate is 0.12181307688414106
# Your highscore = 199 and Game episode is 421, exploration_rate is 0.12120401149972035
# Your highscore = 199 and Game episode is 422, exploration_rate is 0.12059799144222175
# Your highscore = 199 and Game episode is 423, exploration_rate is 0.11999500148501063
# Your highscore = 117 and Game episode is 424, exploration_rate is 0.11939502647758558
# Your highscore = 113 and Game episode is 425, exploration_rate is 0.11879805134519765
# Your highscore = 199 and Game episode is 426, exploration_rate is 0.11820406108847166
# Your highscore = 147 and Game episode is 427, exploration_rate is 0.1176130407830293
# Your highscore = 146 and Game episode is 428, exploration_rate is 0.11702497557911415
# Your highscore = 199 and Game episode is 429, exploration_rate is 0.11643985070121858
# Your highscore = 199 and Game episode is 430, exploration_rate is 0.11585765144771248
# Your highscore = 199 and Game episode is 431, exploration_rate is 0.11527836319047392
# Your highscore = 199 and Game episode is 432, exploration_rate is 0.11470197137452155
# Your highscore = 199 and Game episode is 433, exploration_rate is 0.11412846151764894
# Your highscore = 199 and Game episode is 434, exploration_rate is 0.1135578192100607
# Your highscore = 199 and Game episode is 435, exploration_rate is 0.11299003011401039
# Your highscore = 199 and Game episode is 436, exploration_rate is 0.11242507996344034
# Your highscore = 199 and Game episode is 437, exploration_rate is 0.11186295456362313
# Your highscore = 168 and Game episode is 438, exploration_rate is 0.11130363979080501
# Your highscore = 159 and Game episode is 439, exploration_rate is 0.11074712159185099
# Your highscore = 199 and Game episode is 440, exploration_rate is 0.11019338598389174
# Your highscore = 199 and Game episode is 441, exploration_rate is 0.10964241905397228
# Your highscore = 199 and Game episode is 442, exploration_rate is 0.10909420695870241
# Your highscore = 199 and Game episode is 443, exploration_rate is 0.1085487359239089
# Your highscore = 199 and Game episode is 444, exploration_rate is 0.10800599224428936
# Your highscore = 199 and Game episode is 445, exploration_rate is 0.10746596228306791
# Your highscore = 199 and Game episode is 446, exploration_rate is 0.10692863247165257
# Your highscore = 199 and Game episode is 447, exploration_rate is 0.1063939893092943
# Your highscore = 199 and Game episode is 448, exploration_rate is 0.10586201936274783
# Your highscore = 199 and Game episode is 449, exploration_rate is 0.10533270926593409
# Your highscore = 199 and Game episode is 450, exploration_rate is 0.10480604571960442
# Your highscore = 199 and Game episode is 451, exploration_rate is 0.1042820154910064
# Your highscore = 162 and Game episode is 452, exploration_rate is 0.10376060541355137
# Your highscore = 199 and Game episode is 453, exploration_rate is 0.1032418023864836
# Your highscore = 199 and Game episode is 454, exploration_rate is 0.10272559337455119
# Your highscore = 199 and Game episode is 455, exploration_rate is 0.10221196540767843
# Your highscore = 133 and Game episode is 456, exploration_rate is 0.10170090558064004
# Your highscore = 199 and Game episode is 457, exploration_rate is 0.10119240105273684
# Your highscore = 159 and Game episode is 458, exploration_rate is 0.10068643904747315
# Your highscore = 169 and Game episode is 459, exploration_rate is 0.10018300685223579
# Your highscore = 199 and Game episode is 460, exploration_rate is 0.0996820918179746
# Your highscore = 199 and Game episode is 461, exploration_rate is 0.09918368135888474
# Your highscore = 199 and Game episode is 462, exploration_rate is 0.09868776295209031
# Your highscore = 199 and Game episode is 463, exploration_rate is 0.09819432413732986
# Your highscore = 199 and Game episode is 464, exploration_rate is 0.09770335251664321
# Your highscore = 199 and Game episode is 465, exploration_rate is 0.09721483575406
# Your highscore = 199 and Game episode is 466, exploration_rate is 0.09672876157528969
# Your highscore = 199 and Game episode is 467, exploration_rate is 0.09624511776741324
# Your highscore = 199 and Game episode is 468, exploration_rate is 0.09576389217857617
# Your highscore = 199 and Game episode is 469, exploration_rate is 0.09528507271768329
# Your highscore = 199 and Game episode is 470, exploration_rate is 0.09480864735409487
# Your highscore = 199 and Game episode is 471, exploration_rate is 0.0943346041173244
# Your highscore = 199 and Game episode is 472, exploration_rate is 0.09386293109673778
# Your highscore = 199 and Game episode is 473, exploration_rate is 0.09339361644125409
# Your highscore = 199 and Game episode is 474, exploration_rate is 0.09292664835904782
# Your highscore = 199 and Game episode is 475, exploration_rate is 0.09246201511725258
# Your highscore = 199 and Game episode is 476, exploration_rate is 0.09199970504166631
# Your highscore = 170 and Game episode is 477, exploration_rate is 0.09153970651645797
# Your highscore = 199 and Game episode is 478, exploration_rate is 0.09108200798387568
# Your highscore = 199 and Game episode is 479, exploration_rate is 0.0906265979439563
# Your highscore = 191 and Game episode is 480, exploration_rate is 0.09017346495423652
# Your highscore = 106 and Game episode is 481, exploration_rate is 0.08972259762946533
# Your highscore = 135 and Game episode is 482, exploration_rate is 0.089273984641318
# Your highscore = 199 and Game episode is 483, exploration_rate is 0.0888276147181114
# Your highscore = 199 and Game episode is 484, exploration_rate is 0.08838347664452084
# Your highscore = 199 and Game episode is 485, exploration_rate is 0.08794155926129824
# Your highscore = 199 and Game episode is 486, exploration_rate is 0.08750185146499175
# Your highscore = 199 and Game episode is 487, exploration_rate is 0.08706434220766679
# Your highscore = 199 and Game episode is 488, exploration_rate is 0.08662902049662846
# Your highscore = 199 and Game episode is 489, exploration_rate is 0.08619587539414532
# Your highscore = 199 and Game episode is 490, exploration_rate is 0.08576489601717459
# Your highscore = 199 and Game episode is 491, exploration_rate is 0.08533607153708872
# Your highscore = 199 and Game episode is 492, exploration_rate is 0.08490939117940327
# Your highscore = 199 and Game episode is 493, exploration_rate is 0.08448484422350626
# Your highscore = 199 and Game episode is 494, exploration_rate is 0.08406242000238873
# Your highscore = 199 and Game episode is 495, exploration_rate is 0.08364210790237678
# Your highscore = 199 and Game episode is 496, exploration_rate is 0.0832238973628649
# Your highscore = 199 and Game episode is 497, exploration_rate is 0.08280777787605056
# Your highscore = 199 and Game episode is 498, exploration_rate is 0.08239373898667031
# Your highscore = 107 and Game episode is 499, exploration_rate is 0.08198177029173696
# Your highscore = 157 and Game episode is 500, exploration_rate is 0.08157186144027828
# Your highscore = 122 and Game episode is 501, exploration_rate is 0.0811640021330769
# Your highscore = 177 and Game episode is 502, exploration_rate is 0.08075818212241151
# Your highscore = 197 and Game episode is 503, exploration_rate is 0.08035439121179945
# Your highscore = 198 and Game episode is 504, exploration_rate is 0.07995261925574046
# Your highscore = 199 and Game episode is 505, exploration_rate is 0.07955285615946175
# Your highscore = 199 and Game episode is 506, exploration_rate is 0.07915509187866444
# Your highscore = 178 and Game episode is 507, exploration_rate is 0.07875931641927113
# Your highscore = 199 and Game episode is 508, exploration_rate is 0.07836551983717477
# Your highscore = 177 and Game episode is 509, exploration_rate is 0.07797369223798889
# Your highscore = 199 and Game episode is 510, exploration_rate is 0.07758382377679894
# Your highscore = 199 and Game episode is 511, exploration_rate is 0.07719590465791494
# Your highscore = 170 and Game episode is 512, exploration_rate is 0.07680992513462537
# Your highscore = 188 and Game episode is 513, exploration_rate is 0.07642587550895225
# Your highscore = 159 and Game episode is 514, exploration_rate is 0.07604374613140748
# Your highscore = 133 and Game episode is 515, exploration_rate is 0.07566352740075044
# Your highscore = 49 and Game episode is 516, exploration_rate is 0.07528520976374668
# Your highscore = 181 and Game episode is 517, exploration_rate is 0.07490878371492794
# Your highscore = 199 and Game episode is 518, exploration_rate is 0.0745342397963533
# Your highscore = 199 and Game episode is 519, exploration_rate is 0.07416156859737154
# Your highscore = 199 and Game episode is 520, exploration_rate is 0.07379076075438468
# Your highscore = 199 and Game episode is 521, exploration_rate is 0.07342180695061275
# Your highscore = 199 and Game episode is 522, exploration_rate is 0.07305469791585968
# Your highscore = 199 and Game episode is 523, exploration_rate is 0.07268942442628039
# Your highscore = 199 and Game episode is 524, exploration_rate is 0.07232597730414898
# Your highscore = 199 and Game episode is 525, exploration_rate is 0.07196434741762824
# Your highscore = 129 and Game episode is 526, exploration_rate is 0.0716045256805401
# Your highscore = 149 and Game episode is 527, exploration_rate is 0.0712465030521374
# Your highscore = 199 and Game episode is 528, exploration_rate is 0.0708902705368767
# Your highscore = 199 and Game episode is 529, exploration_rate is 0.07053581918419231
# Your highscore = 199 and Game episode is 530, exploration_rate is 0.07018314008827135
# Your highscore = 199 and Game episode is 531, exploration_rate is 0.06983222438783
# Your highscore = 199 and Game episode is 532, exploration_rate is 0.06948306326589085
# Your highscore = 199 and Game episode is 533, exploration_rate is 0.0691356479495614
# Your highscore = 199 and Game episode is 534, exploration_rate is 0.06878996970981359
# Your highscore = 199 and Game episode is 535, exploration_rate is 0.06844601986126451
# Your highscore = 113 and Game episode is 536, exploration_rate is 0.06810378976195819
# Your highscore = 114 and Game episode is 537, exploration_rate is 0.0677632708131484
# Your highscore = 199 and Game episode is 538, exploration_rate is 0.06742445445908266
# Your highscore = 199 and Game episode is 539, exploration_rate is 0.06708733218678724
# Your highscore = 199 and Game episode is 540, exploration_rate is 0.0667518955258533
# Your highscore = 151 and Game episode is 541, exploration_rate is 0.06641813604822402
# Your highscore = 199 and Game episode is 542, exploration_rate is 0.0660860453679829
# Your highscore = 199 and Game episode is 543, exploration_rate is 0.06575561514114299
# Your highscore = 199 and Game episode is 544, exploration_rate is 0.06542683706543727
# Your highscore = 199 and Game episode is 545, exploration_rate is 0.06509970288011008
# Your highscore = 199 and Game episode is 546, exploration_rate is 0.06477420436570952
# Your highscore = 199 and Game episode is 547, exploration_rate is 0.06445033334388098
# Your highscore = 199 and Game episode is 548, exploration_rate is 0.06412808167716157
# Your highscore = 199 and Game episode is 549, exploration_rate is 0.06380744126877576
# Your highscore = 199 and Game episode is 550, exploration_rate is 0.06348840406243188
# Your highscore = 199 and Game episode is 551, exploration_rate is 0.06317096204211972
# Your highscore = 199 and Game episode is 552, exploration_rate is 0.06285510723190912
# Your highscore = 110 and Game episode is 553, exploration_rate is 0.06254083169574957
# Your highscore = 199 and Game episode is 554, exploration_rate is 0.062228127537270826
# Your highscore = 199 and Game episode is 555, exploration_rate is 0.06191698689958447
# Your highscore = 199 and Game episode is 556, exploration_rate is 0.061607401965086545
# Your highscore = 199 and Game episode is 557, exploration_rate is 0.06129936495526111
# Your highscore = 199 and Game episode is 558, exploration_rate is 0.0609928681304848
# Your highscore = 199 and Game episode is 559, exploration_rate is 0.060687903789832374
# Your highscore = 199 and Game episode is 560, exploration_rate is 0.06038446427088321
# Your highscore = 199 and Game episode is 561, exploration_rate is 0.06008254194952879
# Your highscore = 199 and Game episode is 562, exploration_rate is 0.05978212923978115
# Your highscore = 199 and Game episode is 563, exploration_rate is 0.05948321859358224
# Your highscore = 199 and Game episode is 564, exploration_rate is 0.05918580250061433
# Your highscore = 199 and Game episode is 565, exploration_rate is 0.058889873488111255
# ...
# Your highscore = 199 and Game episode is 813, exploration_rate is 0.016988875991640028
# Your highscore = 199 and Game episode is 814, exploration_rate is 0.016903931611681827
# Your highscore = 199 and Game episode is 815, exploration_rate is 0.01681941195362342
# Your highscore = 199 and Game episode is 816, exploration_rate is 0.016735314893855303
# Your highscore = 199 and Game episode is 817, exploration_rate is 0.016651638319386028
# Your highscore = 199 and Game episode is 818, exploration_rate is 0.0165683801277891
# Your highscore = 199 and Game episode is 819, exploration_rate is 0.016485538227150154
# Your highscore = 199 and Game episode is 820, exploration_rate is 0.0164031105360144
# Your highscore = 199 and Game episode is 821, exploration_rate is 0.01632109498333433
# Your highscore = 199 and Game episode is 822, exploration_rate is 0.016239489508417658
# Your highscore = 199 and Game episode is 823, exploration_rate is 0.01615829206087557
# Your highscore = 199 and Game episode is 824, exploration_rate is 0.01607750060057119
# Your highscore = 199 and Game episode is 825, exploration_rate is 0.015997113097568336
# Your highscore = 199 and Game episode is 826, exploration_rate is 0.015917127532080494
# Your highscore = 199 and Game episode is 827, exploration_rate is 0.01583754189442009
# Your highscore = 199 and Game episode is 828, exploration_rate is 0.01575835418494799
# Your highscore = 199 and Game episode is 829, exploration_rate is 0.01567956241402325
# Your highscore = 199 and Game episode is 830, exploration_rate is 0.015601164601953134
# Your highscore = 199 and Game episode is 831, exploration_rate is 0.015523158778943369
# Your highscore = 199 and Game episode is 832, exploration_rate is 0.015445542985048652
# Your highscore = 199 and Game episode is 833, exploration_rate is 0.015368315270123408
# Your highscore = 199 and Game episode is 834, exploration_rate is 0.01529147369377279
# Your highscore = 199 and Game episode is 835, exploration_rate is 0.015215016325303928
# Your highscore = 120 and Game episode is 836, exploration_rate is 0.015138941243677408
# Your highscore = 199 and Game episode is 837, exploration_rate is 0.01506324653745902
# Your highscore = 199 and Game episode is 838, exploration_rate is 0.014987930304771725
# Your highscore = 199 and Game episode is 839, exploration_rate is 0.014912990653247866
# Your highscore = 199 and Game episode is 840, exploration_rate is 0.014838425699981627
# Your highscore = 135 and Game episode is 841, exploration_rate is 0.01476423357148172
# Your highscore = 111 and Game episode is 842, exploration_rate is 0.014690412403624311
# Your highscore = 199 and Game episode is 843, exploration_rate is 0.01461696034160619
# Your highscore = 199 and Game episode is 844, exploration_rate is 0.014543875539898159
# Your highscore = 131 and Game episode is 845, exploration_rate is 0.014471156162198668
# Your highscore = 195 and Game episode is 846, exploration_rate is 0.014398800381387675
# Your highscore = 199 and Game episode is 847, exploration_rate is 0.014326806379480736
# Your highscore = 199 and Game episode is 848, exploration_rate is 0.014255172347583332
# Your highscore = 199 and Game episode is 849, exploration_rate is 0.014183896485845416
# Your highscore = 199 and Game episode is 850, exploration_rate is 0.014112977003416188
# Your highscore = 199 and Game episode is 851, exploration_rate is 0.014042412118399107
# Your highscore = 199 and Game episode is 852, exploration_rate is 0.013972200057807112
# Your highscore = 199 and Game episode is 853, exploration_rate is 0.013902339057518077
# Your highscore = 199 and Game episode is 854, exploration_rate is 0.013832827362230486
# Your highscore = 97 and Game episode is 855, exploration_rate is 0.013763663225419333
# Your highscore = 199 and Game episode is 856, exploration_rate is 0.013694844909292236
# Your highscore = 199 and Game episode is 857, exploration_rate is 0.013626370684745774
# Your highscore = 199 and Game episode is 858, exploration_rate is 0.013558238831322046
# Your highscore = 199 and Game episode is 859, exploration_rate is 0.013490447637165436
# Your highscore = 199 and Game episode is 860, exploration_rate is 0.013422995398979608
# Your highscore = 199 and Game episode is 861, exploration_rate is 0.01335588042198471
# Your highscore = 199 and Game episode is 862, exploration_rate is 0.013289101019874787
# Your highscore = 199 and Game episode is 863, exploration_rate is 0.013222655514775413
# Your highscore = 199 and Game episode is 864, exploration_rate is 0.013156542237201536
# Your highscore = 199 and Game episode is 865, exploration_rate is 0.013090759526015528
# Your highscore = 199 and Game episode is 866, exploration_rate is 0.01302530572838545
# Your highscore = 199 and Game episode is 867, exploration_rate is 0.012960179199743523
# Your highscore = 94 and Game episode is 868, exploration_rate is 0.012895378303744804
# Your highscore = 27 and Game episode is 869, exploration_rate is 0.01283090141222608
# Your highscore = 27 and Game episode is 870, exploration_rate is 0.012766746905164949
# Your highscore = 94 and Game episode is 871, exploration_rate is 0.012702913170639124
# Your highscore = 98 and Game episode is 872, exploration_rate is 0.012639398604785928
# Your highscore = 26 and Game episode is 873, exploration_rate is 0.012576201611761997
# Your highscore = 17 and Game episode is 874, exploration_rate is 0.012513320603703188
# Your highscore = 20 and Game episode is 875, exploration_rate is 0.012450754000684672
# Your highscore = 98 and Game episode is 876, exploration_rate is 0.012388500230681249
# Your highscore = 100 and Game episode is 877, exploration_rate is 0.012326557729527843
# Your highscore = 199 and Game episode is 878, exploration_rate is 0.012264924940880204
# Your highscore = 103 and Game episode is 879, exploration_rate is 0.012203600316175803
# Your highscore = 86 and Game episode is 880, exploration_rate is 0.012142582314594924
# Your highscore = 23 and Game episode is 881, exploration_rate is 0.01208186940302195
# Your highscore = 12 and Game episode is 882, exploration_rate is 0.01202146005600684
# Your highscore = 13 and Game episode is 883, exploration_rate is 0.011961352755726806
# Your highscore = 10 and Game episode is 884, exploration_rate is 0.01190154599194817
# Your highscore = 15 and Game episode is 885, exploration_rate is 0.01184203826198843
# Your highscore = 13 and Game episode is 886, exploration_rate is 0.011782828070678488
# Your highscore = 12 and Game episode is 887, exploration_rate is 0.011723913930325095
# Your highscore = 9 and Game episode is 888, exploration_rate is 0.01166529436067347
# Your highscore = 9 and Game episode is 889, exploration_rate is 0.011606967888870102
# Your highscore = 9 and Game episode is 890, exploration_rate is 0.01154893304942575
# Your highscore = 15 and Game episode is 891, exploration_rate is 0.011491188384178622
# Your highscore = 20 and Game episode is 892, exploration_rate is 0.011433732442257729
# Your highscore = 15 and Game episode is 893, exploration_rate is 0.01137656378004644
# Your highscore = 9 and Game episode is 894, exploration_rate is 0.011319680961146208
# Your highscore = 10 and Game episode is 895, exploration_rate is 0.011263082556340478
# Your highscore = 11 and Game episode is 896, exploration_rate is 0.011206767143558775
# Your highscore = 9 and Game episode is 897, exploration_rate is 0.011150733307840981
# Your highscore = 12 and Game episode is 898, exploration_rate is 0.011094979641301777
# Your highscore = 14 and Game episode is 899, exploration_rate is 0.011039504743095268
# Your highscore = 9 and Game episode is 900, exploration_rate is 0.01098430721937979
# Your highscore = 14 and Game episode is 901, exploration_rate is 0.010929385683282892
# Your highscore = 12 and Game episode is 902, exploration_rate is 0.010874738754866477
# Your highscore = 11 and Game episode is 903, exploration_rate is 0.010820365061092144
# Your highscore = 12 and Game episode is 904, exploration_rate is 0.010766263235786683
# Your highscore = 15 and Game episode is 905, exploration_rate is 0.01071243191960775
# Your highscore = 21 and Game episode is 906, exploration_rate is 0.010658869760009713
# Your highscore = 100 and Game episode is 907, exploration_rate is 0.010605575411209664
# Your highscore = 199 and Game episode is 908, exploration_rate is 0.010552547534153616
# Your highscore = 199 and Game episode is 909, exploration_rate is 0.010499784796482848
# Your highscore = 199 and Game episode is 910, exploration_rate is 0.010447285872500434
# Your highscore = 199 and Game episode is 911, exploration_rate is 0.01039504944313793
# Your highscore = 199 and Game episode is 912, exploration_rate is 0.010343074195922241
# Your highscore = 199 and Game episode is 913, exploration_rate is 0.01029135882494263
# Your highscore = 179 and Game episode is 914, exploration_rate is 0.010239902030817916
# Your highscore = 193 and Game episode is 915, exploration_rate is 0.010188702520663827
# Your highscore = 199 and Game episode is 916, exploration_rate is 0.010137759008060509
# Your highscore = 199 and Game episode is 917, exploration_rate is 0.010087070213020206
# Your highscore = 199 and Game episode is 918, exploration_rate is 0.010036634861955105
# Your highscore = 199 and Game episode is 919, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 920, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 921, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 922, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 923, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 924, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 925, exploration_rate is 0.00998645168764533
# Your highscore = 109 and Game episode is 926, exploration_rate is 0.00998645168764533
# Your highscore = 93 and Game episode is 927, exploration_rate is 0.00998645168764533
# Your highscore = 114 and Game episode is 928, exploration_rate is 0.00998645168764533
# Your highscore = 140 and Game episode is 929, exploration_rate is 0.00998645168764533
# Your highscore = 152 and Game episode is 930, exploration_rate is 0.00998645168764533
# Your highscore = 196 and Game episode is 931, exploration_rate is 0.00998645168764533
# Your highscore = 118 and Game episode is 932, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 933, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 934, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 935, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 936, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 937, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 938, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 939, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 940, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 941, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 942, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 943, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 944, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 945, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 946, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 947, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 948, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 949, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 950, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 951, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 952, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 953, exploration_rate is 0.00998645168764533
# Your highscore = 23 and Game episode is 954, exploration_rate is 0.00998645168764533
# Your highscore = 94 and Game episode is 955, exploration_rate is 0.00998645168764533
# Your highscore = 105 and Game episode is 956, exploration_rate is 0.00998645168764533
# Your highscore = 182 and Game episode is 957, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 958, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 959, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 960, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 961, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 962, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 963, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 964, exploration_rate is 0.00998645168764533
# Your highscore = 195 and Game episode is 965, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 966, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 967, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 968, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 969, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 970, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 971, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 972, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 973, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 974, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 975, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 976, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 977, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 978, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 979, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 980, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 981, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 982, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 983, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 984, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 985, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 986, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 987, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 988, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 989, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 990, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 991, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 992, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 993, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 994, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 995, exploration_rate is 0.00998645168764533
# Your highscore = 149 and Game episode is 996, exploration_rate is 0.00998645168764533
# Your highscore = 199 and Game episode is 997, exploration_rate is 0.00998645168764533
